# %%
print('Hello, Welcome to Adventure game! You are about to enter a room that is linked to 3 rooms. Each room has a door leading to another room. The goal of the game is to find the exit door of each room. ')

class Room:
    def __init__(self, name, desc):
        self.name = name 
        self.desc = desc 



    
    walls = 4
    doors = 2


room1=Room('bedroom','This room contains a bed, a desk, a chair. It has a door located to the South east part of the room')
room2=Room('temple', 'This room contains numerous religious statues.The exit door is located on the west ')
room3=Room('kitchen',"There is just one massive oven directly south of you. On the west of that oven there is the exit door. ")
room4=Room('Cellar',"It's completely empty but contains one exit door on the east.")
Startgame=input('Do you wish to enter room1 and start the game?')
currentRoom=room1

   

while Startgame != "no":
    print('You are in the {}'.format(currentRoom.name))
    print(currentRoom.desc)
    whichway = input('Which way would you like to go now?')
    if whichway == 'north':
        print("You cannot go this way, you can either go south or east ")
        continue 
    elif whichway == 'west':
        print("You cannot go this way, you can either go south or east ")
        continue
    elif whichway =='south':
        print('Great, you can go south. For your next step I will give you a hint: remember the description of the bedroom, where is the exit door located? ')
        southwhichway=''
        while southwhichway != 'east':
            southwhichway= input('Now that you went south, which way would you like to move?')
            
            if southwhichway == 'north': 
                print('You cannot go this way.')
                continue
            elif southwhichway == 'west':
                print('You cannot go this way')
                continue
            elif southwhichway == 'south':
                print('You cannot go this way')
                continue
            elif southwhichway == "east":
                print('Good choice')
            else: 
                print('Sorry did not get that. Your options for movement are: south, east, west or north.')
        if southwhichway == 'east':
                currentRoom = room2
                print('Congrats you have arrived to the second room. You are in the {}'.format(currentRoom.name))
                break

    elif whichway == 'east': 
        print('Great, you can go east. For your next step I will give you a hint: remember the description of the bedroom, where is the exit door located?')
        eastwhichway = ''
        while eastwhichway != 'south':
            eastwhichway = input('Now that you went east, which way would you like to go?')
            if eastwhichway == 'north':
                print('You cannot go that way')
                continue
            elif eastwhichway =='west':
                print("You cannot go that way")
                continue
            elif eastwhichway == "east":
                print("You cannot go that way")
                continue
            elif eastwhichway == "south": 
                print('good choice')
            else: 
                print('Sorry did not get that. Your options for movement are: south, east, west or north')
        if eastwhichway == "south": 
                currentRoom = room2
                print('Congrats you have arrived to the second room. You are in the {}'.format(currentRoom.name))
                break
                
    else: 
        print('Sorry did not get that. Your options for movement are: south, east, west or north')
        continue
        
#Entry into the bedroom     
while currentRoom == room2:
    print(currentRoom.desc) 
    whichway2=''
    while whichway2 != "west":
        whichway2 = input('Now that you are in room2, which way would you like to go now?')
        if whichway2 == "north":
            print("You can't go this way")
            continue
        elif whichway2 == "south":
            print("You cannot go this way")
            continue
        elif whichway2 == "east":
            print('You cannot go that way')
            continue
        elif whichway2 == "west":
            print('Good choice')
        else: 
            print('Sorry did not get that. Your options for movement are: south, east, west or north')
            continue
    if whichway2 == "west":
        currentRoom = room3
        print('Congrats you have arrived to the third room. You are in the {}'.format(currentRoom.name))
        break
#entry into the kitchen 
while currentRoom == room3:
    print(currentRoom.desc)
    
    whichway3=input('Now that you are in room3, where would you like to go?')
    if whichway3 == "north":
        print("You cannot go this way")
        continue
    elif whichway3 == "east":
        print('You cannot go this way')
        continue 
    elif whichway3 == "south":
        print('Great, you can go south. For your next step I will give you a hint: remember the description of the kitchen, where is the exit door located? ')
        southwhichway=''
        while southwhichway != 'west':
            southwhichway= input('Now that you went south, which way would you like to move?')
            
            if southwhichway == 'north': 
                print('You cannot go this way.')
                continue
            elif southwhichway == 'east':
                print('You cannot go this way')
                continue
            elif southwhichway == 'south':
                print('You cannot go this way')
                continue
            elif southwhichway == "west":
                print('Good choice')
            else: 
                print('Sorry did not get that. Your options for movement are: south, east, west or north.')
        if southwhichway == 'west':
                currentRoom = room4
                print('Congrats you have arrived to the fourth room. You are in the {}'.format(currentRoom.name))
                break
        
    elif whichway3 == "west":
        print('Great, you can go west. For your next step I will give you a hint: remember the description of the kitchen, where is the exit door located?')
        westwhichway = ''
        while westwhichway != 'south':
            westwhichway = input('Now that you went west, which way would you like to go?')
            if westwhichway == 'north':
                print('You cannot go that way')
                continue
            elif westwhichway =='west':
                print("You cannot go that way")
                continue
            elif westwhichway == "east":
                print("You cannot go that way")
                continue
            elif westwhichway == "south": 
                print('good choice')
            else: 
                print('Sorry did not get that. Your options for movement are: south, east, west or north')
                continue
        if westwhichway == "south": 
                currentRoom = room4
                print('Congrats you have arrived to the fourth room. You are in the {}'.format(currentRoom.name))
                break
    else:
        print("Sorry did not get that. Your options for movement are: south, east, west or north")


while currentRoom == room4:
    print(currentRoom.desc)
    whichway4 = ''
    while whichway4 != "east":
        whichway4 = input('Now that you are in room4, which way would you like to go now?')
        if whichway4 == "north":
            print("You can't go this way")
            continue
        elif whichway4 == "south":
            print("You cannot go this way")
            continue
        elif whichway4 == "west":
            print('You cannot go that way')
            continue
        elif whichway4 == "east":
            print('Good choice')
        else: 
            print('Sorry did not get that. Your options for movement are: south, east, west or north')
            continue
    if whichway4 == "east":
        print('Hurray! You have exited the rooms! You have won the game! ')
        break
# Out:
# Hello, Welcome to Adventure game! You are about to enter a room that is linked to 3 rooms. Each room has a door leading to another room. The goal of the game is to find the exit door of each room.
# You are in the bedroom
# This room contains a bed, a desk, a chair. It has a door located to the South east part of the room
# Great, you can go south. For your next step I will give you a hint: remember the description of the bedroom, where is the exit door located?
# Good choice
# Congrats you have arrived to the second room. You are in the temple
# This room contains numerous religious statues.The exit door is located on the west
# Good choice
# Congrats you have arrived to the third room. You are in the kitchen
# There is just one massive oven directly south of you. On the west of that oven there is the exit door.
# You cannot go this way
# There is just one massive oven directly south of you. On the west of that oven there is the exit door.
# ...
